# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests

# %%
url = f"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
if response.status_code == 200:
    response = response.json()
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

# %%
response
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1691056648000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson',
#   'title': 'USGS All Earthquakes, Past Month',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 11227},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.83,
#     'place': '11 km ENE of Julian, CA',
#     'time': 1691056017030,
#     'updated': 1691056638300,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628514',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628514.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'ci',
#     'code': '39628514',
#     'ids': ',ci39628514,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 52,
#     'dmin': 0.09695,
#     'rms': 0.17,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 11 km ENE of Julian, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.4906667, 33.1178333, 10.94]},
#    'id': 'ci39628514'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '86 km N of Karluk, Alaska',
#     'time': 1691055977045,
#     'updated': 1691056084439,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vq6evc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vq6evc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '0239vq6evc',
#     'ids': ',ak0239vq6evc,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 86 km N of Karluk, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.6004, 58.3373, 50]},
#    'id': 'ak0239vq6evc'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '4 km NNE of Knik, Alaska',
#     'time': 1691055914653,
#     'updated': 1691056045065,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vq66yx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vq66yx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '0239vq66yx',
#     'ids': ',ak0239vq66yx,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.58,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 4 km NNE of Knik, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6974, 61.4953, 32.5]},
#    'id': 'ak0239vq66yx'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '28 km N of Paxson, Alaska',
#     'time': 1691055784783,
#     'updated': 1691055941182,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vq5qry',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vq5qry.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ak',
#     'code': '0239vq5qry',
#     'ids': ',ak0239vq5qry,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.32,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 28 km N of Paxson, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-145.5295, 63.3471, 0]},
#    'id': 'ak0239vq5qry'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.79,
#     'place': '2 km NNW of The Geysers, CA',
#     'time': 1691054367890,
#     'updated': 1691055677259,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919711',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919711.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nc',
#     'code': '73919711',
#     'ids': ',nc73919711,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 6,
#     'dmin': 0.0103,
#     'rms': 0.02,
#     'gap': 188,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 2 km NNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7606659, 38.7903328, 0.87]},
#    'id': 'nc73919711'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '29 km SE of Minto, Alaska',
#     'time': 1691053700890,
#     'updated': 1691053790869,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vpy9yh',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vpy9yh.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ak',
#     'code': '0239vpy9yh',
#     'ids': ',ak0239vpy9yh,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.88,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 29 km SE of Minto, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.9501, 64.9514, 15.5]},
#    'id': 'ak0239vpy9yh'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': 'offshore Coquimbo, Chile',
#     'time': 1691053635137,
#     'updated': 1691055130040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kxh9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kxh9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000kxh9',
#     'ids': ',us6000kxh9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 33,
#     'dmin': 0.855,
#     'rms': 1.07,
#     'gap': 144,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - offshore Coquimbo, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.875, -31.6187, 12.854]},
#    'id': 'us6000kxh9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.07,
#     'place': '2 km WNW of Anderson Springs, CA',
#     'time': 1691052600730,
#     'updated': 1691054354141,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919701',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919701.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'nc',
#     'code': '73919701',
#     'ids': ',nc73919701,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.01501,
#     'rms': 0.04,
#     'gap': 172,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 2 km WNW of Anderson Springs, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7128296, 38.7788315, 1.73]},
#    'id': 'nc73919701'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '20 km W of Anchorage, Alaska',
#     'time': 1691052560200,
#     'updated': 1691052703214,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vplmno',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vplmno.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '0239vplmno',
#     'ids': ',ak0239vplmno,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.49,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 20 km W of Anchorage, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.2791, 61.2285, 38.4]},
#    'id': 'ak0239vplmno'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.05,
#     'place': '7 km WNW of Cobb, CA',
#     'time': 1691052333200,
#     'updated': 1691053755094,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919696',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919696.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 17,
#     'net': 'nc',
#     'code': '73919696',
#     'ids': ',nc73919696,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 7,
#     'dmin': 0.006184,
#     'rms': 0.02,
#     'gap': 154,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 7 km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7973328, 38.8354988, 2.1]},
#    'id': 'nc73919696'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.6,
#     'place': '32 km E of Anderson, Alaska',
#     'time': 1691052271405,
#     'updated': 1691052409286,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vpkkxw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vpkkxw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ak',
#     'code': '0239vpkkxw',
#     'ids': ',ak0239vpkkxw,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.13,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 32 km E of Anderson, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.5221, 64.3347, 4.4]},
#    'id': 'ak0239vpkkxw'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.14,
#     'place': '2 km SSE of Frazier Park, CA',
#     'time': 1691051571730,
#     'updated': 1691052222550,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628506',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628506.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 70,
#     'net': 'ci',
#     'code': '39628506',
#     'ids': ',ci39628506,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 52,
#     'dmin': 0.04308,
#     'rms': 0.27,
#     'gap': 52,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 2 km SSE of Frazier Park, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9315, 34.805, 14.15]},
#    'id': 'ci39628506'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.72,
#     'place': '7 km WNW of Cobb, CA',
#     'time': 1691051517320,
#     'updated': 1691053035025,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919686',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919686.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '73919686',
#     'ids': ',nc73919686,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.007684,
#     'rms': 0.04,
#     'gap': 95,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 7 km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7991638, 38.8349991, 1.65]},
#    'id': 'nc73919686'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.00999999,
#     'place': '11 km E of Pāhala, Hawaii',
#     'time': 1691050497020,
#     'updated': 1691050680490,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73508192',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73508192.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'hv',
#     'code': '73508192',
#     'ids': ',hv73508192,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': None,
#     'rms': 0.140000001,
#     'gap': 178,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 11 km E of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.368667602539, 19.2161674499512, 33.7799987792969]},
#    'id': 'hv73508192'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '50 km NNE of Yakutat, Alaska',
#     'time': 1691049705746,
#     'updated': 1691049849796,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vpbe9a',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vpbe9a.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '0239vpbe9a',
#     'ids': ',ak0239vpbe9a,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.11,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 50 km NNE of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-139.4985, 59.9897, 0]},
#    'id': 'ak0239vpbe9a'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.73,
#     'place': '7 km NE of Round Valley, CA',
#     'time': 1691049555320,
#     'updated': 1691052310954,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919676',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919676.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 115,
#     'net': 'nc',
#     'code': '73919676',
#     'ids': ',nc73919676,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 29,
#     'dmin': 0.2144,
#     'rms': 0.07,
#     'gap': 92,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 7 km NE of Round Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.5393295, 37.4604988, 19.36]},
#    'id': 'nc73919676'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '13 km W of Mojave, CA',
#     'time': 1691049501480,
#     'updated': 1691050134450,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628490',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628490.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '39628490',
#     'ids': ',ci39628490,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 22,
#     'dmin': 0.06396,
#     'rms': 0.23,
#     'gap': 43,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 13 km W of Mojave, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.3185, 35.0518333, 7.32]},
#    'id': 'ci39628490'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.06,
#     'place': '18 km SW of Ludlow, CA',
#     'time': 1691049073600,
#     'updated': 1691049295397,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628482',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628482.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 17,
#     'net': 'ci',
#     'code': '39628482',
#     'ids': ',ci39628482,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.1377,
#     'rms': 0.14,
#     'gap': 101,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 18 km SW of Ludlow, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2811667, 34.596, 0.52]},
#    'id': 'ci39628482'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.77,
#     'place': '6 km NW of The Geysers, CA',
#     'time': 1691048756700,
#     'updated': 1691051172852,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919666',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919666.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'nc',
#     'code': '73919666',
#     'ids': ',nc73919666,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 21,
#     'dmin': 0.006066,
#     'rms': 0.02,
#     'gap': 40,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 6 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8044968, 38.8191681, 3.03]},
#    'id': 'nc73919666'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.09,
#     'place': 'Puerto Rico region',
#     'time': 1691048744710,
#     'updated': 1691049476980,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71420323',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71420323.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 67,
#     'net': 'pr',
#     'code': '71420323',
#     'ids': ',pr71420323,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.07791,
#     'rms': 0.09,
#     'gap': 171,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.1 - Puerto Rico region'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8061666666667, 18.0103333333333, 16.02]},
#    'id': 'pr71420323'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '6 km NW of The Geysers, CA',
#     'time': 1691048721500,
#     'updated': 1691050514787,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919661',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919661.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'nc',
#     'code': '73919661',
#     'ids': ',nc73919661,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.006423,
#     'rms': 0.01,
#     'gap': 39,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 6 km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8044968, 38.8186684, 3.11]},
#    'id': 'nc73919661'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.54,
#     'place': '9 km SE of Valle Vista, CA',
#     'time': 1691048669410,
#     'updated': 1691048910103,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628474',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628474.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'ci',
#     'code': '39628474',
#     'ids': ',ci39628474,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.06008,
#     'rms': 0.18,
#     'gap': 118,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 9 km SE of Valle Vista, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.827, 33.6876667, 14.83]},
#    'id': 'ci39628474'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.23,
#     'place': '4 km SE of Loma Linda, CA',
#     'time': 1691048437830,
#     'updated': 1691049098790,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628466',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628466.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'ci',
#     'code': '39628466',
#     'ids': ',ci39628466,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 39,
#     'dmin': 0.08579,
#     'rms': 0.22,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 4 km SE of Loma Linda, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.2261667, 34.021, 18.2]},
#    'id': 'ci39628466'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '50 km S of Silver Peak, Nevada',
#     'time': 1691048108246,
#     'updated': 1691048261394,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00863887',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00863887.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00863887',
#     'ids': ',nn00863887,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.08,
#     'rms': 0.2952,
#     'gap': 176.76,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 50 km S of Silver Peak, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.5922, 37.3009, 3.9]},
#    'id': 'nn00863887'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.92,
#     'place': '2 km NNE of The Geysers, CA',
#     'time': 1691047947090,
#     'updated': 1691055194217,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919656',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919656.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 13,
#     'net': 'nc',
#     'code': '73919656',
#     'ids': ',nc73919656,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.01684,
#     'rms': 0.02,
#     'gap': 151,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 2 km NNE of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7491684, 38.7970009, 0.4]},
#    'id': 'nc73919656'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '41 km WSW of Carlsbad, CA',
#     'time': 1691047799540,
#     'updated': 1691052993863,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628458',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628458.geojson',
#     'felt': 8,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 140,
#     'net': 'ci',
#     'code': '39628458',
#     'ids': ',ci39628458,us6000kxgw,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 94,
#     'dmin': 0.3723,
#     'rms': 0.28,
#     'gap': 164,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 41 km WSW of Carlsbad, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.7491684, 32.9934998, 15.56]},
#    'id': 'ci39628458'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.71,
#     'place': '1 km NNW of The Geysers, CA',
#     'time': 1691047292580,
#     'updated': 1691050997837,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73919641',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73919641.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '73919641',
#     'ids': ',nc73919641,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.01174,
#     'rms': 0.02,
#     'gap': 98,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 1 km NNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.762001, 38.7890015, 1.79]},
#    'id': 'nc73919641'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.96,
#     'place': '24 km SW of Ocotillo Wells, CA',
#     'time': 1691047174830,
#     'updated': 1691047389122,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628450',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628450.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'ci',
#     'code': '39628450',
#     'ids': ',ci39628450,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.02335,
#     'rms': 0.22,
#     'gap': 129,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 24 km SW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2785, 32.965, 10.1]},
#    'id': 'ci39628450'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.99,
#     'place': '1 km ENE of Indios, Puerto Rico',
#     'time': 1691046537170,
#     'updated': 1691047384740,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71420318',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71420318.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 61,
#     'net': 'pr',
#     'code': '71420318',
#     'ids': ',pr71420318,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.0763,
#     'rms': 0.17,
#     'gap': 171,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 1 km ENE of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8046666666667, 18.0031666666667, 15.64]},
#    'id': 'pr71420318'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': 'Central Alaska',
#     'time': 1691046312821,
#     'updated': 1691046402967,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239voqqz6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239voqqz6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ak',
#     'code': '0239voqqz6',
#     'ids': ',ak0239voqqz6,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.24,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - Central Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.8892, 64.2941, 24.9]},
#    'id': 'ak0239voqqz6'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.15,
#     'place': '8 km SSE of Maria Antonia, Puerto Rico',
#     'time': 1691045760870,
#     'updated': 1691046476640,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71420303',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71420303.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 71,
#     'net': 'pr',
#     'code': '71420303',
#     'ids': ',pr71420303,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.07376,
#     'rms': 0.12,
#     'gap': 231,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 8 km SSE of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8548333333333, 17.9046666666667, 16.84]},
#    'id': 'pr71420303'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '88 km NW of Aleneva, Alaska',
#     'time': 1691044780385,
#     'updated': 1691044872071,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vocnsc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vocnsc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '0239vocnsc',
#     'ids': ',ak0239vocnsc,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.35,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 88 km NW of Aleneva, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.1379, 58.5196, 83.3]},
#    'id': 'ak0239vocnsc'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '42 km NNE of Chase, Alaska',
#     'time': 1691044446305,
#     'updated': 1691044572169,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vobimu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vobimu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ak',
#     'code': '0239vobimu',
#     'ids': ',ak0239vobimu,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.87,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 42 km NNE of Chase, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.799, 62.8046, 0]},
#    'id': 'ak0239vobimu'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '6 km NNW of Little Lake, CA',
#     'time': 1691044364330,
#     'updated': 1691045012910,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628434',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628434.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ci',
#     'code': '39628434',
#     'ids': ',ci39628434,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.09248,
#     'rms': 0.13,
#     'gap': 77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 6 km NNW of Little Lake, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9201667, 35.99, 2.85]},
#    'id': 'ci39628434'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '39 km NNE of Chenega, Alaska',
#     'time': 1691044032019,
#     'updated': 1691044175660,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239voa129',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239voa129.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '0239voa129',
#     'ids': ',ak0239voa129,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.6,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 39 km NNE of Chenega, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.766, 60.3999, 17.1]},
#    'id': 'ak0239voa129'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.46,
#     'place': '7 km SW of Niland, CA',
#     'time': 1691043933880,
#     'updated': 1691044144760,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628426',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628426.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 33,
#     'net': 'ci',
#     'code': '39628426',
#     'ids': ',ci39628426,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 7,
#     'dmin': 0.03682,
#     'rms': 0.11,
#     'gap': 103,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 7 km SW of Niland, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.577, 33.195, 2.9]},
#    'id': 'ci39628426'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.03,
#     'place': '51 km N of Cruz Bay, U.S. Virgin Islands',
#     'time': 1691043093770,
#     'updated': 1691044889230,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71420298',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71420298.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 141,
#     'net': 'pr',
#     'code': '71420298',
#     'ids': ',pr71420298,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.488,
#     'rms': 0.24,
#     'gap': 313,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 51 km N of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.7355, 18.7955, 21.8]},
#    'id': 'pr71420298'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.24,
#     'place': '4 km SSW of Indios, Puerto Rico',
#     'time': 1691043059710,
#     'updated': 1691043821220,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71420288',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71420288.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 77,
#     'net': 'pr',
#     'code': '71420288',
#     'ids': ',pr71420288,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.04156,
#     'rms': 0.1,
#     'gap': 205,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 4 km SSW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8391666666667, 17.9585, 15.27]},
#    'id': 'pr71420288'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '16 km SE of Glacier View, Alaska',
#     'time': 1691041817920,
#     'updated': 1691041963647,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vntjds',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vntjds.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '0239vntjds',
#     'ids': ',ak0239vntjds,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.19,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 16 km SE of Glacier View, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.413, 61.7069, 38.4]},
#    'id': 'ak0239vntjds'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '29 km SSW of Pasaco, Guatemala',
#     'time': 1691041596174,
#     'updated': 1691045026341,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kxgi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kxgi.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 272,
#     'net': 'us',
#     'code': '6000kxgi',
#     'ids': ',us6000kxgi,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 52,
#     'dmin': 0.555,
#     'rms': 0.51,
#     'gap': 149,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 29 km SSW of Pasaco, Guatemala'},
#    'geometry': {'type': 'Point', 'coordinates': [-90.3265, 13.7412, 77.321]},
#    'id': 'us6000kxgi'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.97,
#     'place': '9 km ENE of Pāhala, Hawaii',
#     'time': 1691041201250,
#     'updated': 1691041532450,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73508102',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73508102.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 60,
#     'net': 'hv',
#     'code': '73508102',
#     'ids': ',hv73508102,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 151,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 9 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.400833129883, 19.2426662445068, 32.3400001525879]},
#    'id': 'hv73508102'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': 'Halmahera, Indonesia',
#     'time': 1691041160214,
#     'updated': 1691043732040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kxgh',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kxgh.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000kxgh',
#     'ids': ',us6000kxgh,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 2.19,
#     'rms': 0.72,
#     'gap': 108,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - Halmahera, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.1044, 2.8475, 189.923]},
#    'id': 'us6000kxgh'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': 'California-Nevada border region',
#     'time': 1691041038193,
#     'updated': 1691041180470,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00863886',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00863886.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'nn',
#     'code': '00863886',
#     'ids': ',nn00863886,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.695,
#     'rms': 0.2606,
#     'gap': 300.84,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - California-Nevada border region'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.5503, 35.8866, 16]},
#    'id': 'nn00863886'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.45,
#     'place': '7 km SW of Niland, CA',
#     'time': 1691040988840,
#     'updated': 1691045248454,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628410',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628410.geojson',
#     'felt': 3,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 93,
#     'net': 'ci',
#     'code': '39628410',
#     'ids': ',ci39628410,',
#     'sources': ',ci,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 36,
#     'dmin': 0.03996,
#     'rms': 0.25,
#     'gap': 91,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 7 km SW of Niland, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.57, 33.189, 4.24]},
#    'id': 'ci39628410'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.16,
#     'place': '10 km SW of Niland, CA',
#     'time': 1691040988510,
#     'updated': 1691042096040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628402',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628402.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 72,
#     'net': 'ci',
#     'code': '39628402',
#     'ids': ',ci39628402,us6000kxgf,',
#     'sources': ',ci,us,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 12,
#     'dmin': 0.06461,
#     'rms': 0.21,
#     'gap': 208,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 10 km SW of Niland, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.6023331, 33.1831665, 8.59]},
#    'id': 'ci39628402'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': 'Southern Alaska',
#     'time': 1691040773594,
#     'updated': 1691040875321,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vnpr8v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vnpr8v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '0239vnpr8v',
#     'ids': ',ak0239vnpr8v,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.29,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - Southern Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.4427, 60.077, 104.7]},
#    'id': 'ak0239vnpr8v'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': 'Southern Alaska',
#     'time': 1691039784031,
#     'updated': 1691039886435,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vnm9ib',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vnm9ib.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '0239vnm9ib',
#     'ids': ',ak0239vnm9ib,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.4,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - Southern Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.7513, 60.7834, 20.1]},
#    'id': 'ak0239vnm9ib'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.79,
#     'place': '2 km N of Green Acres, CA',
#     'time': 1691039473140,
#     'updated': 1691039687822,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628394',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628394.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ci',
#     'code': '39628394',
#     'ids': ',ci39628394,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.06995,
#     'rms': 0.25,
#     'gap': 59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 2 km N of Green Acres, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.0758333, 33.7555, 6.19]},
#    'id': 'ci39628394'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.39,
#     'place': '24 km SSW of Ocotillo Wells, CA',
#     'time': 1691039463340,
#     'updated': 1691040106340,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39628386',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39628386.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ci',
#     'code': '39628386',
#     'ids': ',ci39628386,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 37,
#     'dmin': 0.05936,
#     'rms': 0.21,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 24 km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2331667, 32.9483333, 12.76]},
#    'id': 'ci39628386'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '55 km NNW of Petersville, Alaska',
#     'time': 1691039421855,
#     'updated': 1691039594671,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vnkz1l',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vnkz1l.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0239vnkz1l',
#     'ids': ',ak0239vnkz1l,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.87,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 55 km NNW of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2475, 62.943, 23.9]},
#    'id': 'ak0239vnkz1l'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '16 km NNE of Sincik, Turkey',
#     'time': 1691038578580,
#     'updated': 1691040615040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kxg6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kxg6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000kxg6',
#     'ids': ',us6000kxg6,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.746,
#     'rms': 1.03,
#     'gap': 60,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 16 km NNE of Sincik, Turkey'},
#    'geometry': {'type': 'Point', 'coordinates': [38.6787, 38.1794, 10]},
#    'id': 'us6000kxg6'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '51 km NNE of Chase, Alaska',
#     'time': 1691037784473,
#     'updated': 1691037891545,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vn6kq7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vn6kq7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ak',
#     'code': '0239vn6kq7',
#     'ids': ',ak0239vn6kq7,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.55,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 51 km NNE of Chase, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.5736, 62.8471, 77.6]},
#    'id': 'ak0239vn6kq7'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '77 km SE of Kokhanok, Alaska',
#     'time': 1691037635866,
#     'updated': 1691037747122,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vn6002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vn6002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0239vn6002',
#     'ids': ',ak0239vn6002,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 77 km SE of Kokhanok, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.9687, 58.8852, 11]},
#    'id': 'ak0239vn6002'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '77 km WNW of Tyonek, Alaska',
#     'time': 1691037044976,
#     'updated': 1691037157300,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0239vn3vjl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0239vn3vjl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0239vn3vjl',
#     'ids': ',ak0239vn3vjl,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.53,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 77 km WNW of Tyonek, Alaska'},
# ...
#    'properties': {'mag': 0.76,
#     'place': '4 km NNW of The Geysers, CA',
#     'time': 1690771708120,
#     'updated': 1690773134875,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73918551',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73918551.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'nc',
#     'code': '73918551',
#     'ids': ',nc73918551,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.002827,
#     'rms': 0.01,
#     'gap': 95,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 4 km NNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7815018, 38.8105011, 1.17]},
#    'id': 'nc73918551'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '5 km E of Petrolia, CA',
#     'time': 1690771599750,
#     'updated': 1690840816316,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73918546',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73918546.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'nc',
#     'code': '73918546',
#     'ids': ',nc73918546,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.04534,
#     'rms': 0.14,
#     'gap': 88,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 5 km E of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.2253333, 40.3268333, 26.09]},
#    'id': 'nc73918546'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': 'northern Mid-Atlantic Ridge',
#     'time': 1690771498835,
#     'updated': 1690836766040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kwsf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kwsf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000kwsf',
#     'ids': ',us6000kwsf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 20.95,
#     'rms': 0.33,
#     'gap': 127,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - northern Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-41.6296, 30.35, 10]},
#    'id': 'us6000kwsf'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.77,
#     'place': 'Rat Islands, Aleutian Islands, Alaska',
#     'time': 1690771471580,
#     'updated': 1690937585160,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91112208',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91112208.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91112208',
#     'ids': ',av91112208,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 203,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.8 - Rat Islands, Aleutian Islands, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [178.557833333333, 51.9625, 4.6]},
#    'id': 'av91112208'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '6 km WNW of The Geysers, CA',
#     'time': 1690771417810,
#     'updated': 1690784837009,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73918541',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73918541.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nc',
#     'code': '73918541',
#     'ids': ',nc73918541,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.008686,
#     'rms': 0.01,
#     'gap': 67,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 6 km WNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8181667, 38.8076667, 2.82]},
#    'id': 'nc73918541'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.64,
#     'place': '4 km WSW of Volcano, Hawaii',
#     'time': 1690771399820,
#     'updated': 1690829203280,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73504277',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73504277.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 41,
#     'net': 'hv',
#     'code': '73504277',
#     'ids': ',hv73504277,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 95,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 4 km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.274333333333, 19.4241666666667, -0.01]},
#    'id': 'hv73504277'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.08,
#     'place': '261 km W of Adak, Alaska',
#     'time': 1690770510740,
#     'updated': 1690934498380,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91984716',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91984716.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91984716',
#     'ids': ',av91984716,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': None,
#     'rms': 0.33,
#     'gap': 121,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.1 - 261 km W of Adak, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [179.568666666667, 51.922, 9.91]},
#    'id': 'av91984716'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '55 km ESE of Lovelock, Nevada',
#     'time': 1690770296644,
#     'updated': 1690841540308,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00863761',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00863761.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'nn',
#     'code': '00863761',
#     'ids': ',nn00863761,',
#     'sources': ',nn,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.259,
#     'rms': 0.2507,
#     'gap': 131.01,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 55 km ESE of Lovelock, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8643, 39.9998, 2]},
#    'id': 'nn00863761'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.02,
#     'place': '10 km ENE of Borrego Springs, CA',
#     'time': 1690769929620,
#     'updated': 1690817693842,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39625866',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39625866.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 16,
#     'net': 'ci',
#     'code': '39625866',
#     'ids': ',ci39625866,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 39,
#     'dmin': 0.07721,
#     'rms': 0.18,
#     'gap': 38,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 10 km ENE of Borrego Springs, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.279, 33.304, 9.55]},
#    'id': 'ci39625866'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '262 km WNW of Houma, Tonga',
#     'time': 1690769763456,
#     'updated': 1690836135040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000kwsa',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000kwsa.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000kwsa',
#     'ids': ',us6000kwsa,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 34,
#     'dmin': 2.447,
#     'rms': 0.61,
#     'gap': 81,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 262 km WNW of Houma, Tonga'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-177.6679, -20.3479, 386.632]},
#    'id': 'us6000kwsa'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.31,
#     'place': 'Fox Islands, Aleutian Islands, Alaska',
#     'time': 1690769729780,
#     'updated': 1690934230130,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91984696',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91984696.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91984696',
#     'ids': ',av91984696,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 142,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.3 - Fox Islands, Aleutian Islands, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-166.8725, 53.902, 5.15]},
#    'id': 'av91984696'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.01,
#     'place': 'Rat Islands, Aleutian Islands, Alaska',
#     'time': 1690769172480,
#     'updated': 1690934058440,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91984681',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91984681.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91984681',
#     'ids': ',av91984681,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': None,
#     'rms': 0.31,
#     'gap': 280,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.0 - Rat Islands, Aleutian Islands, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [179.573, 52.0226666666667, 8.58]},
#    'id': 'av91984681'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.69,
#     'place': '5 km SSE of Banning, CA',
#     'time': 1690768729630,
#     'updated': 1690816917942,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39625858',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39625858.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'ci',
#     'code': '39625858',
#     'ids': ',ci39625858,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.07284,
#     'rms': 0.14,
#     'gap': 91,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 5 km SSE of Banning, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.8593333, 33.8851667, 14.91]},
#    'id': 'ci39625858'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '8 km ENE of Gilroy, CA',
#     'time': 1690768686800,
#     'updated': 1690858154061,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73918536',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73918536.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'nc',
#     'code': '73918536',
#     'ids': ',nc73918536,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 66,
#     'dmin': 0.009931,
#     'rms': 0.13,
#     'gap': 46,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 8 km ENE of Gilroy, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.4855, 37.0353333, 4.68]},
#    'id': 'nc73918536'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.71,
#     'place': '7 km WNW of Cobb, CA',
#     'time': 1690768327050,
#     'updated': 1690769291493,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73918531',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73918531.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '73918531',
#     'ids': ',nc73918531,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.01201,
#     'rms': 0.03,
#     'gap': 84,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 7 km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8054962, 38.8363342, 2.3]},
#    'id': 'nc73918531'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.41,
#     'place': '10 km N of Cabazon, CA',
#     'time': 1690767878890,
#     'updated': 1690813115155,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39625850',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39625850.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 3,
#     'net': 'ci',
#     'code': '39625850',
#     'ids': ',ci39625850,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.03548,
#     'rms': 0.14,
#     'gap': 113,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 10 km N of Cabazon, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.7806667, 34.0076667, 15.01]},
#    'id': 'ci39625850'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.73,
#     'place': '17 km SE of Lincoln, Montana',
#     'time': 1690767858560,
#     'updated': 1690838529840,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb90023003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb90023003.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'mb',
#     'code': '90023003',
#     'ids': ',mb90023003,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.02717,
#     'rms': 0.06,
#     'gap': 134,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 17 km SE of Lincoln, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.496333333333, 46.8561666666667, 10.31]},
#    'id': 'mb90023003'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.28,
#     'place': '83 km NNW of Karluk, Alaska',
#     'time': 1690767763180,
#     'updated': 1690933404860,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91984661',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91984661.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'av',
#     'code': '91984661',
#     'ids': ',av91984661,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': None,
#     'rms': 0.07,
#     'gap': 71,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 83 km NNW of Karluk, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.128, 58.2296666666667, 6.41]},
#    'id': 'av91984661'},
#   ...],
#  'bbox': [-179.9734, -64.0311, -3.2, 179.9645, 82.0207, 653.516]}
